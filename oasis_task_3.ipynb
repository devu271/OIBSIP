# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv')

# %%
df1.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df1.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
def fun(x):
    
    if x=='porcshce':
        return 'porsche'
    
    elif x=='toyouta':
        return 'toyota'
    
    elif x in ['vokswagen','vw']:
        return 'volkswagen'

df1['CarName']=df1['CarName'].apply(lambda x:x.split(' ')[0].lower() if x not in ['porcshce','toyouta','vokswagen','vw'] else fun(x.split(' ')[0].lower()))

# %%
columns=['fueltype','aspiration','carbody','drivewheel','enginelocation','fuelsystem','enginetype']

for col in columns:
    print(col)
    print(df1[col].value_counts())
# Out:
# fueltype
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
# aspiration
# std      168
# turbo     37
# Name: aspiration, dtype: int64
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
# enginelocation
# front    202
# rear       3
# Name: enginelocation, dtype: int64
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
sns.barplot(x=df1['fueltype'],y=df1['price'])
# Out:
# <Axes: xlabel='fueltype', ylabel='price'>

# %% [markdown]
# Price is diesel is more than that of gas

# %%
sns.barplot(x=df1['carbody'],y=df1['price'])
# Out:
# <Axes: xlabel='carbody', ylabel='price'>

# %% [markdown]
# Price of convertible and hardtop carbody appears to be the highest

# %%
sns.barplot(x=df1['drivewheel'],y=df1['price'])
# Out:
# <Axes: xlabel='drivewheel', ylabel='price'>

# %% [markdown]
# Price of rwd drivewheel is highest

# %%
sns.barplot(x=df1['enginelocation'],y=df1['price'])
# Out:
# <Axes: xlabel='enginelocation', ylabel='price'>

# %% [markdown]
# Price of rear enginelocation is more

# %%
sns.barplot(x=df1['fuelsystem'],y=df1['price'])
# Out:
# <Axes: xlabel='fuelsystem', ylabel='price'>

# %% [markdown]
# price of mpfi fuelsystem is highest

# %%
sns.barplot(x=df1['aspiration'],y=df1['price'])
# Out:
# <Axes: xlabel='aspiration', ylabel='price'>

# %% [markdown]
# Price of turbo aspiration is comparitively high

# %%
sns.barplot(x=df1['doornumber'],y=df1['price'])
# Out:
# <Axes: xlabel='doornumber', ylabel='price'>

# %% [markdown]
# The price of both doornumber is almost the same hence we won't include it in our model

# %%
sns.barplot(x=df1['cylindernumber'],y=df1['price'])
# Out:
# <Axes: xlabel='cylindernumber', ylabel='price'>

# %% [markdown]
# cylindernumber is just the number assigned to cylinder. Hence we won't include them in our machine learning model

# %%
sns.barplot(x=df1['enginetype'],y=df1['price'])
# Out:
# <Axes: xlabel='enginetype', ylabel='price'>

# %% [markdown]
# price of dohcv enginetype is highest

# %%
plt.figure(figsize=(18, 8))
sns.barplot(x=df1['compressionratio'],y=df1['price'])
# Out:
# <Axes: xlabel='compressionratio', ylabel='price'>

# %%
plt.figure(figsize=(18, 8))
sns.barplot(x=df1['stroke'],y=df1['price'])
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
plt.figure(figsize=(28, 8))
sns.barplot(x=df1['CarName'],y=df1['price'])
# Out:
# <Axes: xlabel='CarName', ylabel='price'>

# %%
plt.figure(figsize=(28, 8))
sns.boxplot(x=df1['CarName'],y=df1['price'])
# Out:
# <Axes: xlabel='CarName', ylabel='price'>

# %%
sns.distplot(df1['price'],kde=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11680\295953013.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['price'],kde=True)
# <Axes: xlabel='price', ylabel='Density'>

# %%
df1['price'].quantile(0.99)
# Out:
# 40802.72000000003

# %% [markdown]
# Therfore there are no outliers in price column

# %%
sns.lmplot(x='wheelbase',y='price',data=df1)

# %%
sns.lmplot(x='carlength',y='price',data=df1)

# %%
sns.lmplot(x='boreratio',y='price',data=df1)

# %%
sns.lmplot(x='stroke',y='price',data=df1)

# %%
sns.lmplot(x='compressionratio',y='price',data=df1)

# %%
df2=df1[['compressionratio','price']]
#sns.lmplot(x='compressionratio',y='price',data=df1)
df2.head()
# Out:
#    compressionratio    price
# 0               9.0  13495.0
# 1               9.0  16500.0
# 2               9.0  16500.0
# 3              10.0  13950.0
# 4               8.0  17450.0

# %%
sns.lmplot(x='horsepower',y='price',data=df1)

# %%
sns.lmplot(x='peakrpm',y='price',data=df1)

# %%
sns.lmplot(x='citympg',y='price',data=df1)

# %%
sns.lmplot(x='highwaympg',y='price',data=df1)

# %%
df1.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df1.corr()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33496\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# ...

# %%
plt.figure(figsize=(18, 10))
sns.heatmap(df1.corr(),annot=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33496\3130536329.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
columns=['fueltype','aspiration','carbody','drivewheel','enginelocation','fuelsystem']
dfle=df1
for col in columns:
    print(col)
    dfle[col]=le.fit_transform(dfle[col])
# Out:
# fueltype
# aspiration
# carbody
# drivewheel
# enginelocation
# fuelsystem

# %%
dfle['enginetype']=le.fit_transform(dfle['enginetype'])

# %%
dfle.drop(['car_ID','symboling','cylindernumber'],axis=1,inplace=True)
dfle.head()
# Out:
#    fueltype  aspiration  carbody  drivewheel  enginelocation  wheelbase  \
# 0         1           0        0           2               0       88.6
# 1         1           0        0           2               0       88.6
# 2         1           0        2           2               0       94.5
# 3         1           0        3           1               0       99.8
# 4         1           0        3           0               0       99.4
#
#    carlength  carwidth  carheight  curbweight  ...  enginesize  fuelsystem  \
# 0      168.8      64.1       48.8        2548  ...         130           5
# 1      168.8      64.1       48.8        2548  ...         130           5
# 2      171.2      65.5       52.4        2823  ...         152           5
# 3      176.6      66.2       54.3        2337  ...         109           5
# 4      176.6      66.4       54.3        2824  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
columns = ['wheelbase','carlength','carwidth','curbweight','enginesize','boreratio','horsepower',
            'citympg','highwaympg']


dfle[columns]=scaler.fit_transform(dfle[columns])

# %%
dfle.head()
# Out:
#    fueltype  aspiration  carbody  drivewheel  enginelocation  wheelbase  \
# 0         1           0        0           2               0  -1.690772
# 1         1           0        0           2               0  -1.690772
# 2         1           0        2           2               0  -0.708596
# 3         1           0        3           1               0   0.173698
# 4         1           0        3           0               0   0.107110
#
#    carlength  carwidth  carheight  curbweight  ...  enginesize  fuelsystem  \
# 0  -0.426521 -0.844782       48.8   -0.014566  ...    0.074449           5
# 1  -0.426521 -0.844782       48.8   -0.014566  ...    0.074449           5
# 2  -0.231513 -0.190566       52.4    0.514882  ...    0.604046           5
# 3   0.207256  0.136542       54.3   -0.420797  ...   -0.431076           5
# 4   0.207256  0.230001       54.3    0.516807  ...    0.218885           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm   citympg  \
# ...

# %%
dfle.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(dfle.drop('price',axis=1),dfle.price,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9039796216915323

# %%
model.predict(x_test)
# Out:
# array([19789.53413967,  8440.1541177 , 29903.56755204, 14999.41075468,
#        10329.44987026, 15077.27972781, 18236.45121422,  8032.80305158,
#        11363.77325708,  5894.39826588,  9612.17457856,  5818.21951055,
#        10441.07475727,  9044.95375586,  3565.3122729 , 11438.15785719,
#         7448.47613625, 19823.66871495, 20069.57714926, 17091.25808319,
#         7236.22059765,  8909.99819011,  6387.24554035,  8429.59172691,
#         6524.04345543,  6675.13540664,  6031.51581821,  9592.47745058,
#        10172.65986175,  9128.5816306 ,  6512.85190545,  5555.85379777,
#        15504.40788352, 11066.71717277, 15242.41284256,  3932.3951124 ,
#        11346.1283879 , 10473.00404276, 12089.09998066, 20094.19855923,
#        10154.75338177, 12115.69808982, 13678.73287606,  8699.43747693,
#        21324.44979432,  8604.72931702,  7862.87088427, 13519.27864952,
#        29903.56755204, 14997.17244468,  7525.27403358, 11849.99416739,
# ...

# %% [markdown]
# Model accuracy is 90%
